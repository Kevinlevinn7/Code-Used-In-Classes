# %%
from amplpy import AMPL
napkin2 = AMPL()  
napkin2.read('knapsack.mod')
napkin2.readData('knapsack.dat')
napkin2.solve(solver = "highs")
napkin2.display('x', 'Total_Value')
# Out:
# HiGHS 1.11.0HiGHS 1.11.0: optimal solution; objective 2000
# 2 simplex iterations
# 1 branching nodes
# x [*] :=
# a  0
# b  0
# c  0
# d  1
# e  1
# f  1
# g  0
# h  0
# i  0
# j  1
# ;
#
# Total_Value = 2000

# %%
from amplpy import AMPL
napkin2 = AMPL()  
napkin2.read('knapsack2.mod')
napkin2.readData('knapsack.dat')
napkin2.solve(solver = "highs")
napkin2.display('x', 'Total_Value')
# Out:
# HiGHS 1.11.0HiGHS 1.11.0: optimal solution; objective 1950
# 20 simplex iterations
# 1 branching nodes
# x :=
# a 1   0
# a 2   0
# b 1   0
# b 2   0
# c 1   1
# c 2   0
# d 1   0
# d 2   0
# e 1   0
# e 2   1
# f 1   0
# f 2   0
# g 1   0
# g 2   1
# h 1   0
# h 2   0
# i 1   1
# i 2   0
# j 1   0
# j 2   1
# ;
#
# Total_Value = 1950

# %%
from amplpy import AMPL
napkin2 = AMPL()  
napkin2.read('knapsack3.mod')
napkin2.readData('knapsack3.dat')
napkin2.solve(solver = "highs")
napkin2.display('x', 'Total_Value')
# Out:
# HiGHS 1.11.0HiGHS 1.11.0: optimal solution; objective 1700
# 23 simplex iterations
# 1 branching nodes
# x :=
# a 1   0
# a 2   0
# b 1   0
# b 2   0
# c 1   0
# c 2   0
# d 1   0
# d 2   1
# e 1   1
# e 2   0
# f 1   0
# f 2   0
# g 1   0
# g 2   0
# h 1   0
# h 2   1
# i 1   1
# i 2   0
# j 1   0
# j 2   0
# ;
#
# Total_Value = 1700

# %%
from amplpy import AMPL
napkin2 = AMPL()  
napkin2.read('knapsack4.mod')
napkin2.readData('knapsack.dat')
napkin2.solve(solver = "highs")
napkin2.display('x', 'Total_Value')
# Out:
# HiGHS 1.11.0HiGHS 1.11.0: optimal solution; objective 2150
# 0 simplex iterations
# 1 branching nodes
# x [*] :=
# a  0
# b  0
# c  0
# d  1
# e  1
# f  0
# g  0
# h  0
# i  2
# j  3
# ;
#
# Total_Value = 2150
